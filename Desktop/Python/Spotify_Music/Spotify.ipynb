# %% [markdown]
# Feature Engineering and Exploratory Data Analysis

# %%
#Necessary Libraries
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Getting the spotify dataset
spotify=pd.read_csv(r'C:\Users\Ernest\Desktop\Python\Spotify_Music\Spotify.csv')
spotify=spotify.copy()
spotify.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
#Checking the Rows and Columns in the dataset
spotify.shape
# Out:
# (114000, 21)

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
#Having a peek at the summary statistics of the data
spotify.describe().T
# Out:
#                      count           mean            std     min  \
# Unnamed: 0        114000.0   56999.500000   32909.109681   0.000
# popularity        114000.0      33.238535      22.305078   0.000
# duration_ms       114000.0  228029.153114  107297.712645   0.000
# danceability      114000.0       0.566800       0.173542   0.000
# energy            114000.0       0.641383       0.251529   0.000
# key               114000.0       5.309140       3.559987   0.000
# loudness          114000.0      -8.258960       5.029337 -49.531
# mode              114000.0       0.637553       0.480709   0.000
# speechiness       114000.0       0.084652       0.105732   0.000
# acousticness      114000.0       0.314910       0.332523   0.000
# instrumentalness  114000.0       0.156050       0.309555   0.000
# liveness          114000.0       0.213553       0.190378   0.000
# valence           114000.0       0.474068       0.259261   0.000
# ...

# %%
#checking for missing values
spotify.isnull().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
spotify.isna().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
spotify=spotify.dropna()

# %%
spotify.isna().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
# We have to unify naming conventions to all lower characters
#spotify=spotify.columns.str.lower()

# %%
#checking track popularity 
spotify['popularity'].sort_index().reset_index(name='popularity_score')
# Out:
#          index  popularity_score
# 0            0                73
# 1            1                55
# 2            2                57
# 3            3                71
# 4            4                82
# ...        ...               ...
# 113994  113995                21
# 113995  113996                22
# 113996  113997                22
# 113997  113998                41
# 113998  113999                22
#
# [113999 rows x 2 columns]

# %%
#finding the max score and the corresponding track
spotify.loc[spotify['popularity'].idxmax()]
# Out:
# Unnamed: 0                              20001
# track_id               3nqQXoyQOWXiESFLlDF1hG
# artists                  Sam Smith;Kim Petras
# album_name          Unholy (feat. Kim Petras)
# track_name          Unholy (feat. Kim Petras)
# popularity                                100
# duration_ms                            156943
# explicit                                False
# danceability                            0.714
# energy                                  0.472
# key                                         2
# loudness                               -7.375
# mode                                        1
# speechiness                            0.0864
# acousticness                            0.013
# instrumentalness                     0.000005
# liveness                                0.266
# valence                                 0.238
# tempo                                 131.121
# time_signature                              4
# ...

# %%
spotify['chart'] = 0
spotify.loc[spotify['popularity'] > 50, 'chart'] = 1,
spotify
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
spotify.chart.value_counts().reset_index(name="Number_of_tracks")

# %%
#chart distribution
labels = ['less_popular','most_popular']
values = spotify['chart'].value_counts()
values

# %%
plt.bar(labels,values,color=('#006400','#000814'))
for i, v in enumerate(values):
    plt.text(i,v,str(v),ha='center')

# %%
#Artists popularity
artists = spotify.groupby(['artists']).size()
artists = artists.to_frame()
artists.sort_values(by=[0], ascending=False)

# %%
genre = spotify.groupby(['track_genre']).size()
genre = genre.to_frame()
genre.sort_values(by=[0], ascending=False)

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, accuracy_score

y_train_preddt = spotify.predict(X_train)
y_test_preddt = spotify.predict(X_test)

# %%
X=spotify.columns
X=['track_id', 'artists', 'album_name', 'track_name',
       'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
       'key', 'loudness', 'mode', 'speechiness', 'acousticness',
       'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
       'track_genre']
X
